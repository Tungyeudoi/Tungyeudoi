# %% [markdown]
# <a href="https://colab.research.google.com/github/Tungyeudoi/Tungyeudoi/blob/main/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="700")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='700', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# Total files: 9
# [BÁO GIÁ IN ẢNH.pdf] copied. Size 71.25 MB. Speed 70.18 MB/s
# Total files: 76
# Copy at Folder Chu Đức Starting
# [ZAN08473.jpg] copied. Size 0.60 MB. Speed 0.33 MB/s
# [ZAN08474.jpg] copied. Size 0.89 MB. Speed 0.53 MB/s
# [ZAN08475.jpg] copied. Size 0.83 MB. Speed 0.52 MB/s
# [ZAN08476.jpg] copied. Size 0.85 MB. Speed 0.54 MB/s
# [ZAN08477.jpg] copied. Size 0.77 MB. Speed 0.45 MB/s
# [ZAN08478.jpg] copied. Size 0.76 MB. Speed 0.49 MB/s
# [ZAN08479.jpg] copied. Size 0.76 MB. Speed 0.47 MB/s
# [ZAN08480.jpg] copied. Size 1.86 MB. Speed 1.11 MB/s
# [ZAN08481.jpg] copied. Size 2.02 MB. Speed 1.31 MB/s
# [ZAN08482.jpg] copied. Size 2.17 MB. Speed 1.11 MB/s
# [ZAN08488.jpg] copied. Size 2.53 MB. Speed 1.71 MB/s
# [ZAN08489.jpg] copied. Size 2.46 MB. Speed 1.38 MB/s
# [ZAN08490.jpg] copied. Size 2.44 MB. Speed 1.53 MB/s
# [ZAN08491.jpg] copied. Size 2.23 MB. Speed 1.35 MB/s
# [ZAN08492.jpg] copied. Size 2.26 MB. Speed 1.70 MB/s
# [ZAN08498.jpg] copied. Size 1.65 MB. Speed 1.36 MB/s
# [ZAN08499.jpg] copied. Size 1.97 MB. Speed 1.49 MB/s
# [ZAN08500.jpg] copied. Size 2.22 MB. Speed 0.81 MB/s
# [ZAN08501.jpg] copied. Size 1.98 MB. Speed 1.12 MB/s
# [ZAN08502.jpg] copied. Size 1.06 MB. Speed 0.56 MB/s
# [ZAN08503.jpg] copied. Size 1.21 MB. Speed 0.70 MB/s
# [ZAN08504.jpg] copied. Size 1.32 MB. Speed 1.09 MB/s
# [ZAN08509.jpg] copied. Size 1.27 MB. Speed 0.74 MB/s
# [ZAN08510.jpg] copied. Size 1.84 MB. Speed 1.12 MB/s
# [ZAN08511.jpg] copied. Size 1.95 MB. Speed 1.13 MB/s
# [ZAN08512.jpg] copied. Size 2.06 MB. Speed 1.18 MB/s
# [ZAN08513.jpg] copied. Size 1.52 MB. Speed 0.94 MB/s
# [ZAN08514.jpg] copied. Size 1.35 MB. Speed 0.78 MB/s
# [ZAN08515.jpg] copied. Size 1.48 MB. Speed 0.91 MB/s
# [ZAN08516.jpg] copied. Size 1.48 MB. Speed 0.80 MB/s
# [ZAN08523.jpg] copied. Size 0.77 MB. Speed 0.47 MB/s
# [ZAN08524.jpg] copied. Size 0.78 MB. Speed 0.35 MB/s
# [ZAN08525.jpg] copied. Size 0.78 MB. Speed 0.46 MB/s
# [ZAN08526.jpg] copied. Size 0.79 MB. Speed 0.68 MB/s
# [ZAN08527.jpg] copied. Size 0.78 MB. Speed 0.51 MB/s
# [ZAN08532.jpg] copied. Size 1.33 MB. Speed 0.82 MB/s
# [ZAN08533.jpg] copied. Size 1.32 MB. Speed 0.72 MB/s
# [ZAN08534.jpg] copied. Size 1.33 MB. Speed 0.85 MB/s
# [ZAN08535.jpg] copied. Size 1.33 MB. Speed 1.02 MB/s
# [ZAN08536.jpg] copied. Size 1.06 MB. Speed 0.69 MB/s
# [ZAN08537.jpg] copied. Size 0.72 MB. Speed 0.45 MB/s
# [ZAN08538.jpg] copied. Size 0.81 MB. Speed 0.51 MB/s
# [ZAN08539.jpg] copied. Size 0.84 MB. Speed 0.52 MB/s
# [ZAN08540.jpg] copied. Size 0.86 MB. Speed 0.54 MB/s
# [ZAN08541.jpg] copied. Size 0.61 MB. Speed 0.40 MB/s
# [ZAN08542.jpg] copied. Size 0.58 MB. Speed 0.36 MB/s
# [ZAN08543.jpg] copied. Size 0.68 MB. Speed 0.41 MB/s
# [ZAN08544.jpg] copied. Size 0.72 MB. Speed 0.42 MB/s
# [ZAN08545.jpg] copied. Size 0.76 MB. Speed 0.50 MB/s
# [ZAN08546.jpg] copied. Size 0.89 MB. Speed 0.54 MB/s
# [ZAN08547.jpg] copied. Size 0.89 MB. Speed 0.55 MB/s
# [ZAN08548.jpg] copied. Size 0.68 MB. Speed 0.43 MB/s
# [ZAN08549.jpg] copied. Size 0.68 MB. Speed 0.43 MB/s
# [ZAN08550.jpg] copied. Size 0.74 MB. Speed 0.52 MB/s
# [ZAN08551.jpg] copied. Size 0.74 MB. Speed 0.52 MB/s
# [ZAN08552.jpg] copied. Size 0.74 MB. Speed 0.45 MB/s
# [ZAN08553.jpg] copied. Size 0.82 MB. Speed 0.50 MB/s
# [ZAN08554.jpg] copied. Size 0.83 MB. Speed 0.50 MB/s
# [ZAN08555.jpg] copied. Size 0.80 MB. Speed 0.41 MB/s
# [ZAN08556.jpg] copied. Size 0.68 MB. Speed 0.45 MB/s
# [ZAN08557.jpg] copied. Size 0.81 MB. Speed 0.52 MB/s
# [ZAN08558.jpg] copied. Size 0.78 MB. Speed 0.48 MB/s
# [ZAN08559.jpg] copied. Size 0.69 MB. Speed 0.43 MB/s
# [ZAN08560.jpg] copied. Size 0.81 MB. Speed 0.49 MB/s
# [ZAN08561.jpg] copied. Size 0.81 MB. Speed 0.48 MB/s
# [ZAN08562.jpg] copied. Size 0.69 MB. Speed 0.42 MB/s
# [ZAN08563.jpg] copied. Size 0.73 MB. Speed 0.35 MB/s
# [ZAN08564.jpg] copied. Size 1.20 MB. Speed 0.88 MB/s
# [ZAN08565.jpg] copied. Size 1.34 MB. Speed 0.78 MB/s
# [ZAN08566.jpg] copied. Size 1.19 MB. Speed 0.63 MB/s
# [ZAN08568.jpg] copied. Size 0.99 MB. Speed 0.60 MB/s
# [ZAN08569.jpg] copied. Size 1.00 MB. Speed 0.61 MB/s
# [ZAN08570.jpg] copied. Size 1.02 MB. Speed 0.64 MB/s
# [ZAN08571.jpg] copied. Size 1.01 MB. Speed 0.55 MB/s
# [ZAN08572.jpg] copied. Size 0.99 MB. Speed 0.63 MB/s
# [ZAN08573.jpg] copied. Size 1.00 MB. Speed 0.67 MB/s
# Copy at Folder Chu Đức Ending
# Total files: 35
# Copy at Folder Demo Starting
# [DUC02815-Edit-Edit.jpg] copied. Size 0.65 MB. Speed 0.40 MB/s
# [DUC02886-Edit.jpg] copied. Size 0.54 MB. Speed 0.34 MB/s
# [DUC02987-Edit-Edit.jpg] copied. Size 0.83 MB. Speed 0.56 MB/s
# [DUC03105-Edit.jpg] copied. Size 0.94 MB. Speed 0.55 MB/s
# [JAN05333-Edit-2-Edit.jpg] copied. Size 0.78 MB. Speed 0.46 MB/s
# [JAN05349-Edit-Edit.jpg] copied. Size 0.80 MB. Speed 0.53 MB/s
# [JAN05392-Edit-2-Edit.jpg] copied. Size 2.26 MB. Speed 1.66 MB/s
# [JAN05403.jpg] copied. Size 0.83 MB. Speed 0.52 MB/s
# [JAN05441-Edit-Edit.jpg] copied. Size 0.84 MB. Speed 0.72 MB/s
# [JAN05471-Edit.jpg] copied. Size 0.72 MB. Speed 0.45 MB/s
# [JAN05496-Edit-Edit.jpg] copied. Size 1.50 MB. Speed 0.87 MB/s
# [JAN05508-Edit-Edit.jpg] copied. Size 2.21 MB. Speed 1.27 MB/s
# [JAN05613-Edit-Edit.jpg] copied. Size 0.95 MB. Speed 0.58 MB/s
# [JAN05684.jpg] copied. Size 0.89 MB. Speed 0.55 MB/s
# [NTN07961-Edit-Edit.jpg] copied. Size 0.51 MB. Speed 0.32 MB/s
# [NTN08100-Edit-Edit.jpg] copied. Size 1.42 MB. Speed 0.91 MB/s
# [NTN08123-Edit-Edit.jpg] copied. Size 1.61 MB. Speed 1.02 MB/s
# [NTN08162-Edit.jpg] copied. Size 1.29 MB. Speed 0.88 MB/s
# [NTN08164-Edit-Edit.jpg] copied. Size 1.32 MB. Speed 0.78 MB/s
# [NTN08192-Edit.jpg] copied. Size 0.98 MB. Speed 0.64 MB/s
# [NTN08218.jpg] copied. Size 0.79 MB. Speed 0.48 MB/s
# [NTN08236.jpg.jpg] copied. Size 0.56 MB. Speed 0.39 MB/s
# [NTN08249.jpg] copied. Size 0.81 MB. Speed 0.57 MB/s
# [NTN08261.jpg] copied. Size 0.75 MB. Speed 0.51 MB/s
# [NTN08267.jpg] copied. Size 0.87 MB. Speed 0.54 MB/s
# [NTN08287.jpg] copied. Size 0.87 MB. Speed 0.57 MB/s
# [NTN08302.jpg] copied. Size 0.80 MB. Speed 0.73 MB/s
# [NTN08316.jpg] copied. Size 0.80 MB. Speed 0.52 MB/s
# [NTN08378.jpg] copied. Size 0.80 MB. Speed 0.51 MB/s
# [NTN08403.jpg] copied. Size 0.80 MB. Speed 0.55 MB/s
# [NTN08430-Edit-Edit.jpg] copied. Size 0.82 MB. Speed 0.53 MB/s
# [NTN08447-Edit.jpg] copied. Size 1.15 MB. Speed 0.76 MB/s
# [NTN08453.jpg] copied. Size 3.34 MB. Speed 1.80 MB/s
# [NTN08538-Edit.jpg] copied. Size 1.04 MB. Speed 0.62 MB/s
# [ZAN08567-Enhanced-NR-Edit-Edit.jpg] copied. Size 0.76 MB. Speed 0.50 MB/s
# Copy at Folder Demo Ending
# [LƯU Ý XEM ẢNH.pdf] copied. Size 79.87 MB. Speed 108.96 MB/s
# Total files: 2107
# Copy at Folder Nghĩa Starting
# [NTN06641.jpg] copied. Size 0.89 MB. Speed 0.89 MB/s
# [NTN06643.jpg] copied. Size 1.10 MB. Speed 0.71 MB/s
# [NTN06644.jpg] copied. Size 0.85 MB. Speed 0.58 MB/s
# [NTN06645.jpg] copied. Size 0.99 MB. Speed 0.65 MB/s
# [NTN06646.jpg] copied. Size 0.76 MB. Speed 0.69 MB/s
# [NTN06649.jpg] copied. Size 0.71 MB. Speed 0.47 MB/s
# [NTN06650.jpg] copied. Size 1.07 MB. Speed 0.69 MB/s
# [NTN06652.jpg] copied. Size 0.84 MB. Speed 0.86 MB/s
# [NTN06653.jpg] copied. Size 1.00 MB. Speed 0.66 MB/s
# [NTN06654.jpg] copied. Size 0.79 MB. Speed 0.48 MB/s
# [NTN06655.jpg] copied. Size 0.54 MB. Speed 0.35 MB/s
# [NTN06656.jpg] copied. Size 0.93 MB. Speed 0.56 MB/s
# [NTN06657.jpg] copied. Size 1.39 MB. Speed 0.95 MB/s
# [NTN06659.jpg] copied. Size 1.57 MB. Speed 0.98 MB/s
# [NTN06664.jpg] copied. Size 1.13 MB. Speed 1.00 MB/s
# [NTN06666.jpg] copied. Size 0.95 MB. Speed 0.61 MB/s
# [NTN06667.jpg] copied. Size 0.52 MB. Speed 0.33 MB/s
# [NTN06669.jpg] copied. Size 0.71 MB. Speed 0.41 MB/s
# [NTN06678.jpg] copied. Size 1.07 MB. Speed 0.65 MB/s
# [NTN06679.jpg] copied. Size 1.17 MB. Speed 0.82 MB/s
# [NTN06687.jpg] copied. Size 1.84 MB. Speed 1.20 MB/s
# [NTN06688.jpg] copied. Size 1.00 MB. Speed 0.65 MB/s
# [NTN06689.jpg] copied. Size 0.64 MB. Speed 0.43 MB/s
# [NTN06697.jpg] copied. Size 0.82 MB. Speed 0.54 MB/s
# [NTN06702.jpg] copied. Size 0.46 MB. Speed 0.31 MB/s
# [NTN06703.jpg] copied. Size 0.48 MB. Speed 0.30 MB/s
# [NTN06704.jpg] copied. Size 0.46 MB. Speed 0.30 MB/s
# [NTN06705.jpg] copied. Size 0.38 MB. Speed 0.24 MB/s
# [NTN06706.jpg] copied. Size 0.46 MB. Speed 0.29 MB/s
# [NTN06707.jpg] copied. Size 0.49 MB. Speed 0.28 MB/s
# [NTN06708.jpg] copied. Size 0.59 MB. Speed 0.39 MB/s
# [NTN06709.jpg] copied. Size 0.57 MB. Speed 0.39 MB/s
# [NTN06710.jpg] copied. Size 0.56 MB. Speed 0.35 MB/s
# [NTN06711.jpg] copied. Size 0.48 MB. Speed 0.32 MB/s
# [NTN06712.jpg] copied. Size 0.48 MB. Speed 0.31 MB/s
# [NTN06713.jpg] copied. Size 0.50 MB. Speed 0.30 MB/s
# [NTN06714.jpg] copied. Size 0.50 MB. Speed 0.33 MB/s
# [NTN06715.jpg] copied. Size 0.50 MB. Speed 0.32 MB/s
# [NTN06716.jpg] copied. Size 1.43 MB. Speed 0.89 MB/s
# [NTN06717.jpg] copied. Size 2.36 MB. Speed 1.23 MB/s
# [NTN06718.jpg] copied. Size 1.96 MB. Speed 1.80 MB/s
# [NTN06719.jpg] copied. Size 1.93 MB. Speed 1.17 MB/s
# [NTN06720.jpg] copied. Size 0.48 MB. Speed 0.28 MB/s
# [NTN06721.jpg] copied. Size 0.48 MB. Speed 0.47 MB/s
# [NTN06722.jpg] copied. Size 0.48 MB. Speed 0.30 MB/s
# [NTN06723.jpg] copied. Size 0.49 MB. Speed 0.29 MB/s
# [NTN06724.jpg] copied. Size 0.48 MB. Speed 0.33 MB/s
# [NTN06725.jpg] copied. Size 0.47 MB. Speed 0.33 MB/s
# [NTN06726.jpg] copied. Size 0.46 MB. Speed 0.29 MB/s
# [NTN06727.jpg] copied. Size 0.46 MB. Speed 0.32 MB/s
# [NTN06728.jpg] copied. Size 0.46 MB. Speed 0.29 MB/s
# [NTN06729.jpg] copied. Size 1.50 MB. Speed 0.92 MB/s
# [NTN06730.jpg] copied. Size 1.48 MB. Speed 0.88 MB/s
# [NTN06731.jpg] copied. Size 1.49 MB. Speed 0.91 MB/s
# [NTN06732.jpg] copied. Size 1.33 MB. Speed 0.77 MB/s
# [NTN06733.jpg] copied. Size 1.37 MB. Speed 1.24 MB/s
# [NTN06734.jpg] copied. Size 1.40 MB. Speed 0.79 MB/s
# [NTN06735.jpg] copied. Size 1.42 MB. Speed 0.87 MB/s
# [NTN06736.jpg] copied. Size 1.40 MB. Speed 0.88 MB/s
# [NTN06737.jpg] copied. Size 1.13 MB. Speed 0.94 MB/s
# [NTN06738.jpg] copied. Size 1.14 MB. Speed 0.71 MB/s
# [NTN06739.jpg] copied. Size 1.13 MB. Speed 0.71 MB/s
# [NTN06740.jpg] copied. Size 1.15 MB. Speed 0.69 MB/s
# [NTN06741.jpg] copied. Size 1.23 MB. Speed 0.77 MB/s
# [NTN06742.jpg] copied. Size 0.97 MB. Speed 0.68 MB/s
# [NTN06743.jpg] copied. Size 1.11 MB. Speed 0.70 MB/s
# [NTN06744.jpg] copied. Size 0.85 MB. Speed 0.53 MB/s
# [NTN06745.jpg] copied. Size 0.88 MB. Speed 0.53 MB/s
# [NTN06746.jpg] copied. Size 1.23 MB. Speed 0.84 MB/s
# [NTN06747.jpg] copied. Size 1.49 MB. Speed 0.88 MB/s
# [NTN06748.jpg] copied. Size 1.42 MB. Speed 0.83 MB/s
# [NTN06749.jpg] copied. Size 1.74 MB. Speed 1.03 MB/s
# [NTN06750.jpg] copied. Size 1.74 MB. Speed 1.14 MB/s
# [NTN06751.jpg] copied. Size 1.73 MB. Speed 1.18 MB/s
# [NTN06752.jpg] copied. Size 1.73 MB. Speed 1.03 MB/s
# [NTN06753.jpg] copied. Size 1.52 MB. Speed 0.93 MB/s
# [NTN06754.jpg] copied. Size 1.53 MB. Speed 0.89 MB/s
# [NTN06755.jpg] copied. Size 0.83 MB. Speed 0.69 MB/s
# [NTN06756.jpg] copied. Size 0.93 MB. Speed 0.58 MB/s
# [NTN06757.jpg] copied. Size 0.55 MB. Speed 0.33 MB/s
# [NTN06758.jpg] copied. Size 0.56 MB. Speed 0.33 MB/s
# [NTN06759.jpg] copied. Size 0.59 MB. Speed 0.56 MB/s
# [NTN06760.jpg] copied. Size 0.50 MB. Speed 0.32 MB/s
# [NTN06761.jpg] copied. Size 0.50 MB. Speed 0.33 MB/s
# [NTN06762.jpg] copied. Size 0.53 MB. Speed 0.36 MB/s
# [NTN06763.jpg] copied. Size 0.51 MB. Speed 0.31 MB/s
# [NTN06764.jpg] copied. Size 0.52 MB. Speed 0.31 MB/s
# [NTN06765.jpg] copied. Size 0.51 MB. Speed 0.31 MB/s
# [NTN06766.jpg] copied. Size 0.51 MB. Speed 0.33 MB/s
# [NTN06768.jpg] copied. Size 0.53 MB. Speed 0.52 MB/s
# [NTN06769.jpg] copied. Size 0.50 MB. Speed 0.32 MB/s
# [NTN06770.jpg] copied. Size 0.52 MB. Speed 0.44 MB/s
# [NTN06771.jpg] copied. Size 0.52 MB. Speed 0.34 MB/s
# [NTN06772.jpg] copied. Size 0.50 MB. Speed 0.29 MB/s
# [NTN06773.jpg] copied. Size 0.52 MB. Speed 0.34 MB/s
# [NTN06774.jpg] copied. Size 0.51 MB. Speed 0.28 MB/s
# [NTN06775.jpg] copied. Size 0.51 MB. Speed 0.29 MB/s
# [NTN06776.jpg] copied. Size 0.52 MB. Speed 0.34 MB/s
# [NTN06777.jpg] copied. Size 0.53 MB. Speed 0.35 MB/s
# [NTN06778.jpg] copied. Size 0.53 MB. Speed 0.32 MB/s
# [NTN06779.jpg] copied. Size 0.54 MB. Speed 0.35 MB/s
# [NTN06780.jpg] copied. Size 0.53 MB. Speed 0.36 MB/s
# [NTN06781.jpg] copied. Size 0.53 MB. Speed 0.25 MB/s
# [NTN06782.jpg] copied. Size 0.53 MB. Speed 0.37 MB/s
# [NTN06783.jpg] copied. Size 0.52 MB. Speed 0.35 MB/s
# [NTN06784.jpg] copied. Size 0.53 MB. Speed 0.17 MB/s
# [NTN06785.jpg] copied. Size 0.53 MB. Speed 0.38 MB/s
# [NTN06786.jpg] copied. Size 0.46 MB. Speed 0.32 MB/s
# [NTN06787.jpg] copied. Size 0.46 MB. Speed 0.27 MB/s
# [NTN06788.jpg] copied. Size 0.47 MB. Speed 0.34 MB/s
# [NTN06789.jpg] copied. Size 0.48 MB. Speed 0.31 MB/s
# [NTN06790.jpg] copied. Size 0.45 MB. Speed 0.28 MB/s
# [NTN06791.jpg] copied. Size 0.61 MB. Speed 0.38 MB/s
# [NTN06792.jpg] copied. Size 0.62 MB. Speed 0.41 MB/s
# [NTN06793.jpg] copied. Size 0.67 MB. Speed 0.46 MB/s
# [NTN06794.jpg] copied. Size 0.68 MB. Speed 0.43 MB/s
# [NTN06795.jpg] copied. Size 0.64 MB. Speed 0.37 MB/s
# [NTN06796.jpg] copied. Size 0.63 MB. Speed 0.37 MB/s
# [NTN06797.jpg] copied. Size 0.61 MB. Speed 0.36 MB/s
# [NTN06798.jpg] copied. Size 0.61 MB. Speed 0.42 MB/s
# [NTN06799.jpg] copied. Size 0.44 MB. Speed 0.30 MB/s
# [NTN06801.jpg] copied. Size 0.53 MB. Speed 0.28 MB/s
# [NTN06802.jpg] copied. Size 0.67 MB. Speed 0.63 MB/s
# [NTN06803.jpg] copied. Size 0.69 MB. Speed 0.44 MB/s
# [NTN06804.jpg] copied. Size 0.68 MB. Speed 0.43 MB/s
# [NTN06805.jpg] copied. Size 0.64 MB. Speed 0.47 MB/s
# [NTN06806.jpg] copied. Size 0.64 MB. Speed 0.37 MB/s
# [NTN06807.jpg] copied. Size 0.57 MB. Speed 0.35 MB/s
# [NTN06808.jpg] copied. Size 0.58 MB. Speed 0.36 MB/s
# [NTN06809.jpg] copied. Size 0.58 MB. Speed 0.38 MB/s
# [NTN06810.jpg] copied. Size 0.57 MB. Speed 0.38 MB/s
# [NTN06811.jpg] copied. Size 0.56 MB. Speed 0.34 MB/s
# [NTN06812.jpg] copied. Size 0.55 MB. Speed 0.34 MB/s
# [NTN06813.jpg] copied. Size 0.55 MB. Speed 0.38 MB/s
# [NTN06814.jpg] copied. Size 0.55 MB. Speed 0.36 MB/s
# [NTN06815.jpg] copied. Size 0.64 MB. Speed 0.37 MB/s
# [NTN06816.jpg] copied. Size 0.66 MB. Speed 0.38 MB/s
# [NTN06817.jpg] copied. Size 0.64 MB. Speed 0.36 MB/s
# [NTN06819.jpg] copied. Size 0.55 MB. Speed 0.32 MB/s
# [NTN06820.jpg] copied. Size 0.58 MB. Speed 0.43 MB/s
# [NTN06821.jpg] copied. Size 0.60 MB. Speed 0.40 MB/s
# [NTN06822.jpg] copied. Size 0.60 MB. Speed 0.36 MB/s
# [NTN06823.jpg] copied. Size 0.59 MB. Speed 0.38 MB/s
# [NTN06824.jpg] copied. Size 0.60 MB. Speed 0.43 MB/s
# [NTN06825.jpg] copied. Size 0.61 MB. Speed 0.52 MB/s
# [NTN06826.jpg] copied. Size 0.61 MB. Speed 0.35 MB/s
# [NTN06827.jpg] copied. Size 0.60 MB. Speed 0.54 MB/s
# [NTN06828.jpg] copied. Size 0.33 MB. Speed 0.22 MB/s
# [NTN06829.jpg] copied. Size 0.34 MB. Speed 0.21 MB/s
# [NTN06830.jpg] copied. Size 0.34 MB. Speed 0.20 MB/s
# [NTN06831.jpg] copied. Size 0.32 MB. Speed 0.21 MB/s
# [NTN06832.jpg] copied. Size 0.32 MB. Speed 0.22 MB/s
# [NTN06833.jpg] copied. Size 0.31 MB. Speed 0.20 MB/s
# [NTN06834.jpg] copied. Size 0.31 MB. Speed 0.25 MB/s
# [NTN06835.jpg] copied. Size 0.32 MB. Speed 0.19 MB/s
# [NTN06836.jpg] copied. Size 0.31 MB. Speed 0.19 MB/s
# [NTN06837.jpg] copied. Size 0.31 MB. Speed 0.18 MB/s
# [NTN06839.jpg] copied. Size 0.32 MB. Speed 0.20 MB/s
# [NTN06840.jpg] copied. Size 0.33 MB. Speed 0.18 MB/s
# [NTN06841.jpg] copied. Size 0.33 MB. Speed 0.20 MB/s
# [NTN06842.jpg] copied. Size 0.33 MB. Speed 0.21 MB/s
# [NTN06843.jpg] copied. Size 0.33 MB. Speed 0.17 MB/s
# [NTN06844.jpg] copied. Size 0.34 MB. Speed 0.21 MB/s
# [NTN06845.jpg] copied. Size 0.32 MB. Speed 0.21 MB/s
# [NTN06846.jpg] copied. Size 0.32 MB. Speed 0.19 MB/s
# [NTN06847.jpg] copied. Size 0.32 MB. Speed 0.20 MB/s
# [NTN06848.jpg] copied. Size 0.32 MB. Speed 0.21 MB/s
# [NTN06849.jpg] copied. Size 0.29 MB. Speed 0.17 MB/s
# [NTN06850.jpg] copied. Size 0.29 MB. Speed 0.19 MB/s
# [NTN06851.jpg] copied. Size 0.28 MB. Speed 0.18 MB/s
# [NTN06852.jpg] copied. Size 0.28 MB. Speed 0.18 MB/s
# [NTN06853.jpg] copied. Size 0.27 MB. Speed 0.18 MB/s
# [NTN06854.jpg] copied. Size 0.28 MB. Speed 0.16 MB/s
# [NTN06855.jpg] copied. Size 0.28 MB. Speed 0.19 MB/s
# [NTN06857.jpg] copied. Size 0.26 MB. Speed 0.18 MB/s
# [NTN06858.jpg] copied. Size 0.27 MB. Speed 0.24 MB/s
# [NTN06859.jpg] copied. Size 0.21 MB. Speed 0.14 MB/s
# [NTN06860.jpg] copied. Size 0.21 MB. Speed 0.15 MB/s
# [NTN06861.jpg] copied. Size 0.24 MB. Speed 0.16 MB/s
# [NTN06862.jpg] copied. Size 0.23 MB. Speed 0.15 MB/s
# [NTN06863.jpg] copied. Size 0.46 MB. Speed 0.32 MB/s
# [NTN06864.jpg] copied. Size 0.43 MB. Speed 0.29 MB/s
# [NTN06866.jpg] copied. Size 0.49 MB. Speed 0.27 MB/s
# [NTN06867.jpg] copied. Size 0.48 MB. Speed 0.36 MB/s
# [NTN06868.jpg] copied. Size 0.48 MB. Speed 0.33 MB/s
# [NTN06869.jpg] copied. Size 0.51 MB. Speed 0.34 MB/s
# [NTN06871.jpg] copied. Size 0.49 MB. Speed 0.49 MB/s
# [NTN06872.jpg] copied. Size 0.54 MB. Speed 0.37 MB/s
# [NTN06873.jpg] copied. Size 0.53 MB. Speed 0.35 MB/s
# [NTN06874.jpg] copied. Size 0.53 MB. Speed 0.32 MB/s
# [NTN06875.jpg] copied. Size 0.53 MB. Speed 0.32 MB/s
# [NTN06876.jpg] copied. Size 0.54 MB. Speed 0.38 MB/s
# [NTN06877.jpg] copied. Size 0.53 MB. Speed 0.44 MB/s
# [NTN06878.jpg] copied. Size 0.50 MB. Speed 0.34 MB/s
# [NTN06879.jpg] copied. Size 0.52 MB. Speed 0.34 MB/s
# [NTN06880.jpg] copied. Size 0.52 MB. Speed 0.30 MB/s
# [NTN06881.jpg] copied. Size 0.51 MB. Speed 0.53 MB/s
# [NTN06882.jpg] copied. Size 0.49 MB. Speed 0.33 MB/s
# [NTN06883.jpg] copied. Size 0.52 MB. Speed 0.37 MB/s
# [NTN06884.jpg] copied. Size 0.51 MB. Speed 0.32 MB/s
# [NTN06885.jpg] copied. Size 0.51 MB. Speed 0.33 MB/s
# [NTN06886.jpg] copied. Size 0.52 MB. Speed 0.35 MB/s
# [NTN06887.jpg] copied. Size 0.54 MB. Speed 0.35 MB/s
# [NTN06888.jpg] copied. Size 0.54 MB. Speed 0.36 MB/s
# [NTN06889.jpg] copied. Size 0.54 MB. Speed 0.37 MB/s
# [NTN06890.jpg] copied. Size 0.53 MB. Speed 0.37 MB/s
# [NTN06891.jpg] copied. Size 0.53 MB. Speed 0.33 MB/s
# [NTN06892.jpg] copied. Size 0.53 MB. Speed 0.36 MB/s
# [NTN06893.jpg] copied. Size 0.48 MB. Speed 0.28 MB/s
# [NTN06894.jpg] copied. Size 0.51 MB. Speed 0.33 MB/s
# [NTN06895.jpg] copied. Size 0.72 MB. Speed 0.44 MB/s
# [NTN06897.jpg] copied. Size 0.55 MB. Speed 0.35 MB/s
# [NTN06898.jpg] copied. Size 0.58 MB. Speed 0.36 MB/s
# [NTN06899.jpg] copied. Size 0.70 MB. Speed 0.47 MB/s
# [NTN06900.jpg] copied. Size 0.69 MB. Speed 0.52 MB/s
# [NTN06901.jpg] copied. Size 0.63 MB. Speed 0.42 MB/s
# [NTN06902.jpg] copied. Size 0.63 MB. Speed 0.42 MB/s
# [NTN06903.jpg] copied. Size 0.58 MB. Speed 0.37 MB/s
# [NTN06904.jpg] copied. Size 0.66 MB. Speed 0.61 MB/s
# [NTN06905.jpg] copied. Size 0.67 MB. Speed 0.42 MB/s
# [NTN06906.jpg] copied. Size 0.69 MB. Speed 0.44 MB/s
# [NTN06907.jpg] copied. Size 0.69 MB. Speed 0.23 MB/s
# [NTN06908.jpg] copied. Size 0.73 MB. Speed 0.48 MB/s
# [NTN06909.jpg] copied. Size 0.75 MB. Speed 0.41 MB/s
# [NTN06910.jpg] copied. Size 0.65 MB. Speed 0.43 MB/s
# [NTN06911.jpg] copied. Size 0.66 MB. Speed 0.70 MB/s
# [NTN06912.jpg] copied. Size 0.68 MB. Speed 0.59 MB/s
# [NTN06913.jpg] copied. Size 0.67 MB. Speed 0.41 MB/s
# [NTN06914.jpg] copied. Size 0.65 MB. Speed 0.43 MB/s
# [NTN06915.jpg] copied. Size 0.65 MB. Speed 0.43 MB/s
# [NTN06916.jpg] copied. Size 0.59 MB. Speed 0.36 MB/s
# [NTN06917.jpg] copied. Size 0.60 MB. Speed 0.37 MB/s
# [NTN06918.jpg] copied. Size 0.63 MB. Speed 0.42 MB/s
# [NTN06919.jpg] copied. Size 0.59 MB. Speed 0.36 MB/s
# [NTN06920.jpg] copied. Size 0.64 MB. Speed 0.54 MB/s
# [NTN06921.jpg] copied. Size 0.59 MB. Speed 0.32 MB/s
# [NTN06922.jpg] copied. Size 0.61 MB. Speed 0.41 MB/s
# [NTN06923.jpg] copied. Size 0.60 MB. Speed 0.40 MB/s
# [NTN06924.jpg] copied. Size 0.62 MB. Speed 0.42 MB/s
# [NTN06925.jpg] copied. Size 0.62 MB. Speed 0.38 MB/s
# [NTN06926.jpg] copied. Size 0.62 MB. Speed 0.37 MB/s
# [NTN06927.jpg] copied. Size 0.51 MB. Speed 0.37 MB/s
# [NTN06928.jpg] copied. Size 0.57 MB. Speed 0.36 MB/s
# [NTN06929.jpg] copied. Size 0.46 MB. Speed 0.29 MB/s
# [NTN06930.jpg] copied. Size 0.58 MB. Speed 0.39 MB/s
# [NTN06931.jpg] copied. Size 0.58 MB. Speed 0.38 MB/s
# [NTN06932.jpg] copied. Size 0.45 MB. Speed 0.30 MB/s
